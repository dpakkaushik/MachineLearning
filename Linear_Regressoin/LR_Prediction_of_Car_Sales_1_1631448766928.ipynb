# %% [markdown]
# <center>
# <h1> Linear Regression Case Study
# </center>
#
# ### Steps for Regression Modeling:
# 1. Business problem definition - One of major automobile company would like to design new product which can improve the sales. Inorder to define the product, they want to understand/identify drivers for the sales (what are the factors driving sales) and Predicting sales of different car models given driving factors.
# 2. Convert business problem into statistical problem  sales = F(sales attributes, product features, marketing info etc.)
# 3. Finding the right technique - Since it is predicting value (Regression Problem) problem so we can use OLS as one of the technique. We can also use other techniques like Decision Trees, Ensemble learning, KNN, SVM, ANN etc.
# 4. Data colletion(Y, X) - Identify the sources of information and collect the data
# 5. Consolidate the data - aggregate and consolidate the data at Model level/customer level/store level depends on business problem
# 6. Data preparation for modeling (create data audit report to identify the steps to perform as part of data preparation)
#     a. missing value treatment
#     b. outlier treatment
#     c. dummy variable creation
# 7. Variable creation by using transformation and derived variable creation.
# 8. Basic assumptions (Normality, linearity, no outliers, homoscadasticity, no pattern in residuals, no auto correlation etc)
# 9. Variable reduction techniques (removing multicollinerity with the help of FA/PCA, correlation matrics, VIF)
# 10. Create dev and validation data sets (50:50 if you have more data else 70:30 or 80:20)
# 11. Modeling on dev data set (identify significant variables, model interpretation, check the signs and coefficients, multi-collinierity check, measures of good neess fit, final mathematical equation etc)
# 12. validating on validation data set (check the stability of model, scoring, decile analysis, cross validation etc.)
# 13. Output interpretation and derive insights (understand the limitations of the model and define strategy to implementation)
# 14. convert statistical solution into business solutions (implementation, model monitoring etc)

# %% [markdown]
# ### import the packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %matplotlib inline

# %%
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# from sklearn.linear_model import LinearRegression
# sklearn - scikit learn

# %% [markdown]
# ### create UDFs

# %%
def continuous_var_summary( x ):
    
    # freq and missings
    n_total = x.shape[0]
    n_miss = x.isna().sum()
    perc_miss = n_miss * 100 / n_total
    
    # outliers - iqr
    q1 = x.quantile(0.25)
    q3 = x.quantile(0.75)
    iqr = q3 - q1
    lc_iqr = q1 - 1.5 * iqr
    uc_iqr = q3 + 1.5 * iqr
    
    return pd.Series( [ x.dtype, x.nunique(), n_total, x.count(), n_miss, perc_miss,
                       x.sum(), x.mean(), x.std(), x.var(), 
                       lc_iqr, uc_iqr, 
                       x.min(), x.quantile(0.01), x.quantile(0.05), x.quantile(0.10), 
                       x.quantile(0.25), x.quantile(0.5), x.quantile(0.75), 
                       x.quantile(0.90), x.quantile(0.95), x.quantile(0.99), x.max() ], 
                     
                    index = ['dtype', 'cardinality', 'n_tot', 'n', 'nmiss', 'perc_miss',
                             'sum', 'mean', 'std', 'var',
                        'lc_iqr', 'uc_iqr',
                        'min', 'p1', 'p5', 'p10', 'p25', 'p50', 'p75', 'p90', 'p95', 'p99', 'max'])

# %%
# Create Data audit Report for categorical variables
def categorical_var_summary( x ):
    
    Mode = x.value_counts().sort_values(ascending = False)[0:1].reset_index()
    return pd.Series([x.count(), x.isnull().sum(), Mode.iloc[0, 0], Mode.iloc[0, 1], 
                          round(Mode.iloc[0, 1] * 100 / x.count(), 2)], 
                     
                  index = ['N', 'NMISS', 'MODE', 'FREQ', 'PERCENT'])

# %%
# Missing value imputation for continuous variables
def missing_imputation( x, stats = 'mean' ):
    if (x.dtypes == 'float64') | (x.dtypes == 'int64'):
        x = x.fillna(x.mean()) if stats == 'mean' else x.fillna(x.median())
    return x

# %%
# An utility function to create dummy variable
def create_dummies(df, colname):
    col_dummies = pd.get_dummies(df[colname], prefix = colname, drop_first = True)
    df = pd.concat([df, col_dummies], axis = 1)
    df.drop(colname, axis = 1, inplace = True )
    return df

# %% [markdown]
# ### import data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/Data Sets/"

cars = pd.read_csv(path + 'Car.csv')

cars
# Out:
#     Manufacturer    Model   Sales  four_year_resale_value Vehicle_type  \
# 0          Acura  Integra  16.919                  16.360    Passenger
# 1          Acura       TL  39.384                  19.875    Passenger
# 2          Acura       CL  14.114                  18.225    Passenger
# 3          Acura       RL   8.588                  29.725    Passenger
# 4           Audi       A4  20.397                  22.255    Passenger
# ..           ...      ...     ...                     ...          ...
# 152        Volvo      V40   3.545                     NaN    Passenger
# 153        Volvo      S70  15.245                     NaN    Passenger
# 154        Volvo      V70  17.531                     NaN    Passenger
# 155        Volvo      C70   3.493                     NaN    Passenger
# 156        Volvo      S80  18.969                     NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 2                   NaN          3.2       225.0      106.9   70.6   192.0
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0          2.639           13.2             28.0    02-02-2012
# 1          3.517           17.2             25.0    06-03-2011
# 2          3.470           17.2             26.0    01-04-2012
# 3          3.850           18.0             22.0    03-10-2011
# 4          2.998           16.4             27.0    10-08-2011
# ..           ...            ...              ...           ...
# 152        3.042           15.8             25.0     9/21/2011
# 153        3.208           17.9             25.0    11/24/2012
# 154        3.259           17.9             25.0     6/25/2011
# 155        3.601           18.5             23.0     4/26/2011
# 156        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# 2                  NaN
# 3            91.389779
# 4            62.777639
# ..                 ...
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655
#
# [157 rows x 16 columns]

# %% [markdown]
# ### Data inspection

# %%
cars.nunique()
# Out:
# Manufacturer               30
# Model                     156
# Sales                     157
# four_year_resale_value    117
# Vehicle_type                2
# Price_in_thousands        152
# Engine_size                31
# Horsepower                 66
# Wheelbase                  88
# Width                      78
# Length                    127
# Curb_weight               147
# Fuel_capacity              55
# Fuel_efficiency            20
# Latest_Launch             130
# Power_perf_factor         154
# dtype: int64

# %%
# method 1: divide the data into training and testing
train, test = train_test_split( cars, test_size = 0.2, random_state = 12345 )
print(train.shape)
print(test.shape)
# Out:
# (125, 16)
# (32, 16)

# %%
train.rename(columns={'Sales_in_thousands': 'Sales'}, inplace=True)
print(train.shape)
train
# Out:
# (125, 16)
#     Manufacturer           Model   Sales  four_year_resale_value Vehicle_type  \
# 95    Mercedes-B        SL-Class   3.311                  58.600    Passenger
# 146   Volkswagen           Jetta  83.721                  13.240    Passenger
# 65      Infiniti             I30  23.713                  19.690    Passenger
# 99    Mercedes-B           CL500   0.954                     NaN    Passenger
# 122      Pontiac      Bonneville  35.945                  13.225    Passenger
# ..           ...             ...     ...                     ...          ...
# 34      Chrysler            300M  30.696                     NaN    Passenger
# 101       Nissan          Sentra  42.643                   8.450    Passenger
# 126      Porsche  Carrera Cabrio   1.866                  67.550    Passenger
# 129       Saturn              SL  80.620                   9.200    Passenger
# 29      Chrysler   Sebring Conv.  32.775                  14.180    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 95               82.600          5.0       302.0       99.0   71.3   177.1
# 146              16.700          2.0       115.0       98.9   68.3   172.3
# 65               29.465          3.0       227.0      108.3   70.2   193.7
# 99               85.500          5.0       302.0      113.6   73.1   196.6
# 122              23.755          3.8       205.0      112.2   72.6   202.5
# ..                  ...          ...         ...        ...    ...     ...
# 34               29.185          3.5       253.0      113.0   74.4   197.8
# 101              13.499          1.8       126.0       99.8   67.3   177.5
# 126              74.970          3.4       300.0       92.6   69.5   174.5
# 129              10.685          1.9       100.0      102.4   66.4   176.9
# 29               24.495          2.5       168.0      106.0   69.2   193.0
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 95         4.125           21.1             20.0     3/17/2011
# 146        2.853           14.5             26.0     8/27/2011
# 65         3.342           18.5             25.0     4/15/2012
# 99         4.115           23.2             20.0     4/11/2011
# 122        3.590           17.5             24.0     5/18/2011
# ..           ...            ...              ...           ...
# 34         3.567           17.0             23.0     2/10/2012
# 101        2.593           13.2             30.0     8/31/2011
# 126        3.075           17.0             23.0     7/11/2011
# 129        2.332           12.1             33.0     8/16/2012
# 29         3.332           16.0             24.0    11/17/2011
#
#      Power_perf_factor
# 95          139.982294
# 146          47.638237
# 65           92.436889
# 99          141.100985
# 122          82.661356
# ..                 ...
# 34          101.655244
# 101          50.241978
# 126         135.914710
# 129          39.986425
# 29           69.521355
#
# [125 rows x 16 columns]

# %%
test.rename(columns={'Sales_in_thousands': 'Sales'}, inplace=True)
print(test.shape)
test
# Out:
# (32, 16)
#     Manufacturer           Model    Sales  four_year_resale_value  \
# 70         Lexus           ES300   24.072                  26.975
# 42         Dodge         Ram Van   31.038                  13.425
# 56          Ford        F-Series  540.561                  15.075
# 35         Dodge            Neon   76.034                   7.750
# 16      Cadillac        Eldorado    6.536                  25.725
# 24     Chevrolet        Corvette   17.947                  36.225
# 132       Saturn              LW    8.472                     NaN
# 10         Buick         Century   91.561                  12.475
# 140       Toyota          Tacoma   84.087                   9.575
# 86       Mercury        Mystique   14.351                   8.800
# 17      Cadillac          Catera   11.185                  18.225
# 134       Subaru         Outback   47.107                     NaN
# 130       Saturn              SC   24.546                  10.590
# 71         Lexus           GS300   12.698                  32.075
# 148   Volkswagen          Cabrio    9.569                  16.575
# 85    Mitsubishi   Montero Sport   39.348                  13.880
# 28      Chrysler   Sebring Coupe    7.854                  12.360
# 133       Saturn              LS   49.989                     NaN
# 94    Mercedes-B         S-Class   16.774                  50.375
# 69          Jeep  Grand Cherokee  157.040                  18.810
# 60         Honda        Passport   12.855                  17.525
# 92    Mercedes-B         C-Class   18.392                  26.050
# 33      Chrysler  Town & Country   53.480                  19.540
# 112   Oldsmobile         Bravada   20.017                  19.925
# 47          Ford         Mustang  113.369                  12.760
# 102       Nissan          Altima   88.094                  11.295
# 4           Audi              A4   20.397                  22.255
# 55          Ford          Ranger  220.650                   7.850
# 2          Acura              CL   14.114                  18.225
# 155        Volvo             C70    3.493                     NaN
# 19     Chevrolet        Cavalier  145.519                   9.250
# 48          Ford         Contour   35.068                   8.835
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 70     Passenger              31.505          3.0       210.0      105.1
# 42           Car              18.575          3.9       175.0      127.2
# 56           Car              26.935          4.6       220.0      138.5
# 35     Passenger              12.640          2.0       132.0      105.0
# 16     Passenger              39.665          4.6       275.0      108.0
# 24     Passenger              45.705          5.7       345.0      104.5
# 132    Passenger              18.835          2.2       137.0      106.5
# 10     Passenger              21.975          3.1       175.0      109.0
# 140          Car              11.528          2.4       142.0      103.3
# 86     Passenger              16.240          2.0       125.0      106.5
# 17     Passenger              31.010          3.0       200.0      107.4
# 134    Passenger              22.695          2.5       165.0      103.5
# 130    Passenger              12.535          1.9       100.0      102.4
# 71     Passenger              37.805          3.0       225.0      110.2
# 148    Passenger              19.990          2.0       115.0       97.4
# 85           Car              22.527          3.0       173.0      107.3
# 28     Passenger              19.840          2.5       163.0      103.7
# 133    Passenger              15.010          2.2       137.0      106.5
# 94     Passenger              69.700          4.3       275.0      121.5
# 69           Car              26.895          4.0       195.0      105.9
# 60           Car              26.600          3.2       205.0      106.4
# 92     Passenger              31.750          2.3       185.0      105.9
# 33           Car                 NaN          NaN         NaN        NaN
# 112          Car              31.598          4.3       190.0      107.0
# 47     Passenger              21.560          3.8       190.0      101.3
# 102    Passenger              20.390          2.4       155.0      103.1
# 4      Passenger              23.990          1.8       150.0      102.6
# 55           Car              12.050          2.5       119.0      117.5
# 2      Passenger                 NaN          3.2       225.0      106.9
# 155    Passenger              45.500          2.3       236.0      104.9
# 19     Passenger              13.260          2.2       115.0      104.1
# 48     Passenger              17.035          2.5       170.0      106.5
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 70    70.5   190.2        3.373           18.5             23.0      7/9/2012
# 42    78.8   208.5        4.298           32.0             16.0     7/26/2012
# 56    79.1   224.5        4.241           25.1             18.0     8/16/2012
# 35    74.4   174.4        2.567           12.5             29.0    12/12/2011
# 16    75.5   200.6        3.843           19.0             22.0    11/27/2011
# 24    73.6   179.7        3.210           19.1             22.0     5/12/2012
# 132   69.0   190.4        3.075           13.1             27.0      8/5/2011
# 10    72.7   194.6        3.368           17.5             25.0     11/2/2011
# 140   66.5   178.7        2.580           15.1             23.0      8/1/2011
# 86    69.1   184.8        2.769           15.0             28.0    12/19/2012
# 17    70.3   194.8        3.770           18.0             22.0     9/28/2011
# 134   67.5   185.8        3.415           16.9             25.0      7/7/2011
# 130   66.4   180.0        2.367           12.1             33.0     3/16/2011
# 71    70.9   189.2        3.638           19.8             23.0     5/10/2012
# 148   66.7   160.4        3.079           13.7             26.0     5/31/2011
# 85    66.7   178.3        3.510           19.5             20.0     5/18/2012
# 28    69.7   190.9        2.967           15.9             24.0     1/16/2012
# 133   69.0   190.4        2.910           13.1             28.0     12/4/2012
# 94    73.1   203.1        4.133           23.2             21.0     6/13/2011
# 69    72.3   181.5        3.880           20.5             19.0    12/10/2011
# 60    70.4   178.2        3.857           21.1             19.0     10/9/2012
# 92    67.7   177.4        3.250           16.4             26.0     4/24/2011
# 33     NaN     NaN          NaN            NaN              NaN     7/13/2011
# 112   67.8   181.2        4.068           17.5             19.0     9/21/2011
# 47    73.1   183.2        3.203           15.7             24.0     1/31/2012
# 102   69.1   183.5        3.012           15.9             25.0      8/2/2011
# 4     68.2   178.0        2.998           16.4             27.0     10/8/2011
# 55    69.4   200.7        3.086           20.0             23.0     1/14/2012
# 2     70.6   192.0        3.470           17.2             26.0      1/4/2012
# 155   71.5   185.7        3.601           18.5             23.0     4/26/2011
# 19    67.9   180.9        2.676           14.3             27.0     8/17/2011
# 48    69.1   184.6        2.769           15.0             25.0     8/20/2012
#
#      Power_perf_factor
# 70           87.211001
# 42           70.078322
# 56           89.401935
# 35           52.084899
# 16          113.765874
# 24          141.141150
# 132          56.295243
# 10           71.181451
# 140          55.297117
# 86           50.997748
# 17           83.483094
# 134          67.765908
# 130          40.700072
# 71           94.946698
# 148          48.907372
# 85           70.660942
# 28           65.957184
# 133          54.819728
# 94          125.273876
# 69           80.387779
# 60           83.602501
# 92           78.280731
# 33                 NaN
# 112          80.511673
# 47           76.509185
# 102          63.313728
# 4            62.777639
# 55           47.389531
# 2                  NaN
# 155         101.623357
# 19           46.363347
# 48           67.351011

# %% [raw]
# .columns
# .dtypes
# .shape
#
# .info()
# .describe()
# .head()
# .tail()

# %%
cars.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
cars.shape
# Out:
# (157, 16)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Manufacturer            157 non-null    object
#  1   Model                   157 non-null    object
#  2   Sales_in_thousands      157 non-null    float64
#  3   four_year_resale_value  121 non-null    float64
#  4   Vehicle_type            157 non-null    object
#  5   Price_in_thousands      155 non-null    float64
#  6   Engine_size             156 non-null    float64
#  7   Horsepower              156 non-null    float64
#  8   Wheelbase               156 non-null    float64
#  9   Width                   156 non-null    float64
#  10  Length                  156 non-null    float64
#  11  Curb_weight             155 non-null    float64
#  12  Fuel_capacity           156 non-null    float64
#  13  Fuel_efficiency         154 non-null    float64
#  14  Latest_Launch           157 non-null    object
#  15  Power_perf_factor       155 non-null    float64
# dtypes: float64(12), object(4)
# memory usage: 19.8+ KB

# %%
cars.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0   172.4        2.639           13.2             28.0      2/2/2012
# 1   192.9        3.517           17.2             25.0      6/3/2011
# 2   192.0        3.470           17.2             26.0      1/4/2012
# 3   196.6        3.850           18.0             22.0     3/10/2011
# 4   178.0        2.998           16.4             27.0     10/8/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# 3          91.389779
# 4          62.777639

# %%
# no of unique values / cardinality
cars.nunique()
# Out:
# Manufacturer               30
# Model                     156
# Sales_in_thousands        157
# four_year_resale_value    117
# Vehicle_type                2
# Price_in_thousands        152
# Engine_size                31
# Horsepower                 66
# Wheelbase                  88
# Width                      78
# Length                    127
# Curb_weight               147
# Fuel_capacity              55
# Fuel_efficiency            20
# Latest_Launch             130
# Power_perf_factor         154
# dtype: int64

# %%
cars.Vehicle_type.value_counts()
# Out:
# Passenger    116
# Car           41
# Name: Vehicle_type, dtype: int64

# %%
# type conversion in case variables are not of proper type : Not required in this data

# %%
# in case we have huge data and we dont want to make the copy of the original data 
# we generally go with the option of getting column/variable names for obejat and numeric type

numeric_columns = cars.select_dtypes(include = ['float64', 'int64']).columns
object_columns = cars.select_dtypes(include = ['object']).columns

# %%
cars[ object_columns ].head(2)
# Out:
#   Manufacturer    Model Vehicle_type Latest_Launch
# 0        Acura  Integra    Passenger      2/2/2012
# 1        Acura       TL    Passenger      6/3/2011

# %%
cars[ numeric_columns ].head(2)
# Out:
#    Sales_in_thousands  four_year_resale_value  Price_in_thousands  \
# 0              16.919                  16.360                21.5
# 1              39.384                  19.875                28.4
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
#
#    Fuel_capacity  Fuel_efficiency  Power_perf_factor
# 0           13.2             28.0          58.280150
# 1           17.2             25.0          91.370778

# %% [markdown]
# ## or

# %%
# seperate object and numeric variables
cars_conti_vars = cars.loc[:, (cars.dtypes == 'float64') | (cars.dtypes == 'int64')]
cars_cat_vars = cars.loc[:, (cars.dtypes == 'object')]

# Simper way of doing:
# cars_conti_vars = cars.select_dtypes(include = ['float64', 'int64'])
# car_sales_cat = cars.select_dtypes(include = ['object'])

# %%
# alternate of .describe() for continuous variables
cars_conti_vars.apply( continuous_var_summary )

# cars_conti_vars.apply( lambda x: continuous_var_summary(x)).round(1)
# Out:
#             Sales_in_thousands four_year_resale_value Price_in_thousands  \
# dtype                  float64                float64            float64
# cardinality                157                    117                152
# n_tot                      157                    157                157
# n                          157                    121                155
# nmiss                        0                     36                  2
# perc_miss                  0.0              22.929936           1.273885
# sum                   8320.698                2186.83           4245.567
# mean                 52.998076              18.072975          27.390755
# std                  68.029422              11.453384          14.351653
# var                4628.002257             131.180007         205.969949
# lc_iqr                 -66.649                -1.6625            -2.8775
# uc_iqr                 148.719                32.7975            52.8425
# min                       0.11                   5.16              9.235
# p1                     0.93728                  6.173           10.23144
# p5                      1.8708                   7.85             12.469
# p10                     5.4536                  9.125            13.9708
# p25                     14.114                  11.26            18.0175
# p50                      29.45                  14.18             22.799
# p75                     67.956                 19.875            31.9475
# p90                   127.6416                 32.075             44.017
# p95                   185.3362                  41.25             55.835
# p99                  260.64532                  60.22            78.4798
# max                    540.561                  67.55               85.5
#
#             Engine_size   Horsepower   Wheelbase      Width      Length  \
# dtype           float64      float64     float64    float64     float64
# cardinality          31           66          88         78         127
# n_tot               157          157         157        157         157
# n                   156          156         156        156         156
# nmiss                 1            1           1          1           1
# perc_miss      0.636943     0.636943    0.636943   0.636943    0.636943
# sum               477.5      29008.0     16768.0    11099.4     29225.6
# mean           3.060897   185.948718  107.487179      71.15   187.34359
# std            1.044653    56.700321    7.641303   3.451872   13.431754
# var              1.0913  3214.926385   58.389512  11.915419  180.412023
# lc_iqr           0.3875        51.25        89.2    60.8625      149.75
# uc_iqr           5.4875       313.25       126.0    80.9625      223.95
# min                 1.0         55.0        92.6       62.6       149.4
# p1                1.555         96.4      92.875     66.085     154.915
# p5                  1.8        114.5      95.875       66.5     163.675
# p10                1.95        120.0       98.65       66.9       173.0
# p25                 2.3        149.5       103.0       68.4     177.575
# p50                 3.0        177.5       107.0      70.55       187.9
# p75               3.575        215.0       112.2     73.425     196.125
# p90                 4.6        254.0       115.5       76.2       203.4
# p95               4.775        300.0      119.25       78.2       208.5
# p99                 5.7       325.75     134.375      79.19     219.305
# max                 8.0        450.0       138.7       79.9       224.5
#
#             Curb_weight Fuel_capacity Fuel_efficiency Power_perf_factor
# dtype           float64       float64         float64           float64
# cardinality         147            55              20               154
# n_tot               157           157             157               157
# n                   155           156             154               155
# nmiss                 2             1               3                 2
# perc_miss      1.273885      0.636943        1.910828          1.273885
# sum             523.594        2800.5          3672.0      11941.756636
# mean           3.378026     17.951923       23.844156         77.043591
# std            0.630502      3.887921        4.282706         25.142664
# var            0.397532     15.115932       18.341567        632.153558
# lc_iqr          1.72825       10.1375            13.5         16.896951
# uc_iqr          5.04225       25.2375            33.5        132.925634
# min               1.895          10.3            15.0         23.276272
# p1               2.2454          11.9            15.0          38.46192
# p5               2.4235          12.5           16.65         46.203997
# p10              2.6062          13.2            18.3         48.447741
# p25               2.971          15.8            21.0         60.407707
# p50               3.342          17.2            24.0         72.030917
# p75              3.7995        19.575            26.0         89.414878
# p90              4.1186          23.2            28.7        108.499252
# p95              4.3891          25.4            31.0        125.091513
# p99             5.39668          30.9            33.0        141.119461
# max               5.572          32.0            45.0        188.144323

# %%
# alternate of .describe() for categorical variables
cars_cat_vars.apply(categorical_var_summary).T
# Out:
#                  N NMISS       MODE FREQ PERCENT
# Manufacturer   157     0      Dodge   11    7.01
# Model          157     0       Neon    2    1.27
# Vehicle_type   157     0  Passenger  116   73.89
# Latest_Launch  157     0  5/31/2011    2    1.27

# %% [markdown]
# ### outlier treatment

# %%
cars_conti_vars = cars_conti_vars.apply( lambda x: x.clip(lower = x.quantile(0.01),
                                                         upper = x.quantile(0.99)))

# %%
cars_conti_vars.apply(continuous_var_summary)
# Out:
#             Sales_in_thousands four_year_resale_value Price_in_thousands  \
# dtype                  float64                float64            float64
# cardinality                155                    115                150
# n_tot                      157                    157                157
# n                          157                    121                155
# nmiss                        0                     36                  2
# perc_miss                  0.0              22.929936           1.273885
# sum                  8025.5292               2180.421         4235.95548
# mean                  51.11802              18.020008          27.328745
# std                  57.722699              11.181335           14.06397
# var                3331.909938              125.02226         197.795238
# lc_iqr                 -66.649                -1.6625            -2.8775
# uc_iqr                 148.719                32.7975            52.8425
# min                    0.93728                  6.173           10.23144
# p1                    0.946643                 6.4234          10.476362
# p5                      1.8708                   7.85             12.469
# p10                     5.4536                  9.125            13.9708
# p25                     14.114                  11.26            18.0175
# p50                      29.45                  14.18             22.799
# p75                     67.956                 19.875            31.9475
# p90                   127.6416                 32.075             44.017
# p95                   185.3362                  41.25             55.835
# p99                 253.560581                 59.896          76.584508
# max                  260.64532                  60.22            78.4798
#
#             Engine_size   Horsepower   Wheelbase      Width      Length  \
# dtype           float64      float64     float64    float64     float64
# cardinality          29           64          87         76         125
# n_tot               157          157         157        157         157
# n                   156          156         156        156         156
# nmiss                 1            1           1          1           1
# perc_miss      0.636943     0.636943    0.636943   0.636943    0.636943
# sum              475.81      28910.3     16760.1   11102.45    29223.94
# mean           3.050064   185.322436  107.436538  71.169551  187.332949
# std            0.982279     52.81647    7.424295   3.390339    13.12035
# var            0.964871  2789.579526   55.120156    11.4944  172.143594
# lc_iqr           0.3875        51.25        89.2    60.8625      149.75
# uc_iqr           5.4875       313.25       126.0    80.9625      223.95
# min               1.555         96.4      92.875     66.085     154.915
# p1              1.57975        98.38    92.99875   66.25825   156.22675
# p5                  1.8        114.5      95.875       66.5     163.675
# p10                1.95        120.0       98.65       66.9       173.0
# p25                 2.3        149.5       103.0       68.4     177.575
# p50                 3.0        177.5       107.0      70.55       187.9
# p75               3.575        215.0       112.2     73.425     196.125
# p90                 4.6        254.0       115.5       76.2       203.4
# p95               4.775        300.0      119.25       78.2       208.5
# p99                 5.7     317.0875   132.51875    79.1405   217.10225
# max                 5.7       325.75     134.375      79.19     219.305
#
#             Curb_weight Fuel_capacity Fuel_efficiency Power_perf_factor
# dtype           float64       float64         float64           float64
# cardinality         145            54              19               152
# n_tot               157           157             157               157
# n                   155           156             154               155
# nmiss                 2             1               3                 2
# perc_miss      1.273885      0.636943        1.910828          1.273885
# sum           523.77016        2799.9          3660.0      11911.685368
# mean           3.379162     17.948077       23.766234         76.849583
# std            0.621764      3.819854        3.994755         23.844968
# var            0.386591     14.591287       15.958068         568.58248
# lc_iqr          1.72825       10.1375            13.5         16.896951
# uc_iqr          5.04225       25.2375            33.5        132.925634
# min              2.2454          11.9            15.0          38.46192
# p1             2.247884          11.9            15.0         39.285152
# p5               2.4235          12.5           16.65         46.203997
# p10              2.6062          13.2            18.3         48.447741
# p25               2.971          15.8            21.0         60.407707
# p50               3.342          17.2            24.0         72.030917
# p75              3.7995        19.575            26.0         89.414878
# p90              4.1186          23.2            28.7        108.499252
# p95              4.3891          25.4            31.0        125.091513
# p99            5.394693        30.405            33.0        141.109484
# max             5.39668          30.9            33.0        141.119461

# %% [markdown]
# ### missing value treatment

# %%
cars_conti_vars.isna().sum() * 100 / cars_conti_vars.isna().count()
# Out:
# Sales_in_thousands         0.000000
# four_year_resale_value    22.929936
# Price_in_thousands         1.273885
# Engine_size                0.636943
# Horsepower                 0.636943
# Wheelbase                  0.636943
# Width                      0.636943
# Length                     0.636943
# Curb_weight                1.273885
# Fuel_capacity              0.636943
# Fuel_efficiency            1.910828
# Power_perf_factor          1.273885
# dtype: float64

# %%
cars_conti_vars = cars_conti_vars.apply( missing_imputation )

# %%
cars_conti_vars.apply(continuous_var_summary)
# Out:
#             Sales_in_thousands four_year_resale_value Price_in_thousands  \
# dtype                  float64                float64            float64
# cardinality                155                    116                151
# n_tot                      157                    157                157
# n                          157                    157                157
# nmiss                        0                      0                  0
# perc_miss                  0.0                    0.0                0.0
# sum                  8025.5292            2829.141298         4290.61297
# mean                  51.11802              18.020008          27.328745
# std                  57.722699                9.80668          13.973525
# var                3331.909938              96.170969         195.259402
# lc_iqr                 -66.649                 4.1525            -2.5325
# uc_iqr                 148.719                26.5325            52.6075
# min                    0.93728                  6.173           10.23144
# p1                    0.946643                6.87412          10.485434
# p5                      1.8708                  8.425             12.491
# p10                     5.4536                   9.71            13.9762
# p25                     14.114                 12.545             18.145
# p50                      29.45                  17.71               23.4
# p75                     67.956                  18.14              31.93
# p90                   127.6416                 27.025             43.788
# p95                   185.3362                 39.275             55.225
# p99                 253.560581                59.3128          76.514312
# max                  260.64532                  60.22            78.4798
#
#             Engine_size    Horsepower     Wheelbase         Width  \
# dtype           float64       float64       float64       float64
# cardinality          30            65            88            77
# n_tot               157           157           157           157
# n                   157           157           157           157
# nmiss                 0             0             0             0
# perc_miss           0.0           0.0           0.0           0.0
# sum          478.860064  29095.622436  16867.536538  11173.619551
# mean           3.050064    185.322436    107.436538     71.169551
# std            0.979125     52.646914      7.400461      3.379455
# var            0.958686   2771.697606     54.766822     11.420718
# lc_iqr              0.5          52.5          89.2          60.9
# uc_iqr              5.3         312.5         126.0          80.9
# min               1.555          96.4        92.875        66.085
# p1               1.5802        98.416        93.001       66.2614
# p5                  1.8         114.6         95.92          66.5
# p10                1.96         120.0          98.7          66.9
# p25                 2.3         150.0         103.0          68.4
# p50                 3.0         180.0         107.0          70.6
# p75                 3.5         215.0         112.2          73.4
# p90                 4.6         253.8        115.46         76.18
# p95                4.76         300.0         119.2          78.2
# p99                 5.7        316.93       132.485       79.1396
# max                 5.7        325.75       134.375         79.19
#
#                    Length Curb_weight Fuel_capacity Fuel_efficiency  \
# dtype             float64     float64       float64         float64
# cardinality           126         146            55              20
# n_tot                 157         157           157             157
# n                     157         157           157             157
# nmiss                   0           0             0               0
# perc_miss             0.0         0.0           0.0             0.0
# sum          29411.272949  530.528485   2817.848077     3731.298701
# mean           187.332949    3.379162     17.948077       23.766234
# std              13.07823    0.617766      3.807591        3.956157
# var             171.04011    0.381634     14.497753       15.651182
# lc_iqr             149.85      1.7705         10.25            13.5
# uc_iqr             223.85      4.9825         25.05            33.5
# min               154.915      2.2454          11.9            15.0
# p1               156.2506    2.247976          11.9            15.0
# p5                  163.7       2.424          12.5            16.8
# p10                173.12      2.6128          13.2            18.6
# p25                 177.6       2.975          15.8            21.0
# p50                 187.8       3.368          17.2            24.0
# p75                 196.1       3.778          19.5            26.0
# p90                203.34      4.1174          23.2            28.4
# p95                 208.5      4.3884          25.4            31.0
# p99              217.0622    5.394619        30.396            33.0
# max               219.305     5.39668          30.9            33.0
#
#             Power_perf_factor
# dtype                 float64
# cardinality               153
# n_tot                     157
# n                         157
# nmiss                       0
# perc_miss                 0.0
# sum              12065.384534
# mean                76.849583
# std                 23.691622
# var                561.292961
# lc_iqr              17.715715
# uc_iqr             132.413666
# min                  38.46192
# p1                  39.315643
# p5                  46.257114
# p10                 48.522793
# p25                 60.727447
# p50                 72.290355
# p75                 89.401935
# p90                 107.99432
# p95                125.065461
# p99                141.109114
# max                141.119461

# %% [markdown]
# ## Handling categorical features
#
# scikit-learn expects all features to be numeric. So how do we include a categorical feature in our model?
#
# - **Ordered categories:** transform them to sensible numeric values (example: small=1, medium=2, large=3)
# - **Unordered categories:** use dummy encoding (0/1)
#
# What are the categorical features in our dataset?
#
# - **Ordered categories:** weather (already encoded with sensible numeric values)
# - **Unordered categories:** season (needs dummy encoding), holiday (already dummy encoded), workingday (already dummy encoded)
#
# For season, we can't simply leave the encoding as 1 = spring, 2 = summer, 3 = fall, and 4 = winter, because that would imply an **ordered relationship**. Instead, we create **multiple dummy variables:**

# %% [raw]
# # Steps to be followed to create dummy variables:
# -----------------------------------------------------------------------------------------------
# 1. use pd.get_dummies() method to create dummy varaibles for each value inside the variable
# 2. drop any one variable from the dummy variables to avoid multicolinearity
# 3. concat the dummy data with the original dataset
# 4. drop the variable from which dummy variable has been created

# %%
cars_cat_vars.columns
# Out:
# Index(['Manufacturer', 'Model', 'Vehicle_type', 'Latest_Launch'], dtype='object')

# %%
cars_cat_vars.Vehicle_type.nunique()
# Out:
# 2

# %% [markdown]
# **in case we have categorical featue as numeric type, we have to first convert the variable into
# category type**

# %%
# get the useful categorical variables
cars_cat_vars = cars.loc[:, ['Manufacturer', 'Vehicle_type']]

for var in cars_cat_vars.columns:
    df_temp = pd.get_dummies( cars_cat_vars[var], prefix = var, drop_first = True )
    cars_cat_vars = pd.concat( [cars_cat_vars, df_temp], axis = 1 )
    cars_cat_vars.drop( columns = var, inplace=True)
# Out:
# Index(['Manufacturer', 'Vehicle_type'], dtype='object')

# %%
# get the useful categorical variables
cars_cat_vars = cars.loc[:, ['Manufacturer', 'Vehicle_type']]

# for c_feature in categorical_features
for c_feature in cars_cat_vars.columns:
    
    # cars_cat_vars.loc[:, c_feature] = cars_cat_vars[c_feature].astype('category') # you can skip this step for this example; required for the numeric variables
    cars_cat_vars = create_dummies(cars_cat_vars, c_feature)
    
# see the data in the output
#cars_cat_vars

# %% [markdown]
# ##### all the variable names should follow the INC rules going further

# %%
cars_cat_vars.columns
# Out:
# Index(['Manufacturer_Audi', 'Manufacturer_BMW', 'Manufacturer_Buick',
#        'Manufacturer_Cadillac', 'Manufacturer_Chevrolet',
#        'Manufacturer_Chrysler', 'Manufacturer_Dodge', 'Manufacturer_Ford',
#        'Manufacturer_Honda', 'Manufacturer_Hyundai', 'Manufacturer_Infiniti',
#        'Manufacturer_Jaguar', 'Manufacturer_Jeep', 'Manufacturer_Lexus',
#        'Manufacturer_Lincoln', 'Manufacturer_Mercedes-B',
#        'Manufacturer_Mercury', 'Manufacturer_Mitsubishi',
#        'Manufacturer_Nissan', 'Manufacturer_Oldsmobile',
#        'Manufacturer_Plymouth', 'Manufacturer_Pontiac', 'Manufacturer_Porsche',
#        'Manufacturer_Saab', 'Manufacturer_Saturn', 'Manufacturer_Subaru',
#        'Manufacturer_Toyota', 'Manufacturer_Volkswagen', 'Manufacturer_Volvo',
#        'Vehicle_type_Passenger'],
#       dtype='object')

# %%
len(cars_cat_vars.columns)
# Out:
# 30

# %%
cars_cat_vars.rename( columns = {'Manufacturer_Mercedes-B' : 'Manufacturer_Mercedes_B'}, 
                      inplace = True )

# re - regular expressions : pattern search and replace

# %%
cars_cat_vars.columns
# Out:
# Index(['Manufacturer_Audi', 'Manufacturer_BMW', 'Manufacturer_Buick',
#        'Manufacturer_Cadillac', 'Manufacturer_Chevrolet',
#        'Manufacturer_Chrysler', 'Manufacturer_Dodge', 'Manufacturer_Ford',
#        'Manufacturer_Honda', 'Manufacturer_Hyundai', 'Manufacturer_Infiniti',
#        'Manufacturer_Jaguar', 'Manufacturer_Jeep', 'Manufacturer_Lexus',
#        'Manufacturer_Lincoln', 'Manufacturer_Mercedes_B',
#        'Manufacturer_Mercury', 'Manufacturer_Mitsubishi',
#        'Manufacturer_Nissan', 'Manufacturer_Oldsmobile',
#        'Manufacturer_Plymouth', 'Manufacturer_Pontiac', 'Manufacturer_Porsche',
#        'Manufacturer_Saab', 'Manufacturer_Saturn', 'Manufacturer_Subaru',
#        'Manufacturer_Toyota', 'Manufacturer_Volkswagen', 'Manufacturer_Volvo',
#        'Vehicle_type_Passenger'],
#       dtype='object')

# %% [markdown]
# ### final data for analysis

# %%
cars_conti_vars.columns
# Out:
# Index(['Sales_in_thousands', 'four_year_resale_value', 'Price_in_thousands',
#        'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length',
#        'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor'],
#       dtype='object')

# %%
cars_cat_vars.columns
# Out:
# Index(['Manufacturer_Audi', 'Manufacturer_BMW', 'Manufacturer_Buick',
#        'Manufacturer_Cadillac', 'Manufacturer_Chevrolet',
#        'Manufacturer_Chrysler', 'Manufacturer_Dodge', 'Manufacturer_Ford',
#        'Manufacturer_Honda', 'Manufacturer_Hyundai', 'Manufacturer_Infiniti',
#        'Manufacturer_Jaguar', 'Manufacturer_Jeep', 'Manufacturer_Lexus',
#        'Manufacturer_Lincoln', 'Manufacturer_Mercedes_B',
#        'Manufacturer_Mercury', 'Manufacturer_Mitsubishi',
#        'Manufacturer_Nissan', 'Manufacturer_Oldsmobile',
#        'Manufacturer_Plymouth', 'Manufacturer_Pontiac', 'Manufacturer_Porsche',
#        'Manufacturer_Saab', 'Manufacturer_Saturn', 'Manufacturer_Subaru',
#        'Manufacturer_Toyota', 'Manufacturer_Volkswagen', 'Manufacturer_Volvo',
#        'Vehicle_type_Passenger'],
#       dtype='object')

# %% [markdown]
# ##### combine the data ( continuous and categorical ) for further processing

# %%
cars_new = pd.concat([cars_conti_vars, cars_cat_vars], axis = 1)

# %%
cars_new.shape
# Out:
# (157, 42)

# %%
cars_new.head()
# Out:
#    Sales_in_thousands  four_year_resale_value  Price_in_thousands  \
# 0              16.919                  16.360           21.500000
# 1              39.384                  19.875           28.400000
# 2              14.114                  18.225           27.328745
# 3               8.588                  29.725           42.000000
# 4              20.397                  22.255           23.990000
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 2          3.2       225.0      106.9   70.6   192.0        3.470
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
#
#    Fuel_capacity  ...  Manufacturer_Plymouth  Manufacturer_Pontiac  \
# 0           13.2  ...                      0                     0
# 1           17.2  ...                      0                     0
# 2           17.2  ...                      0                     0
# 3           18.0  ...                      0                     0
# 4           16.4  ...                      0                     0
#
#    Manufacturer_Porsche  Manufacturer_Saab  Manufacturer_Saturn  \
# 0                     0                  0                    0
# 1                     0                  0                    0
# 2                     0                  0                    0
# 3                     0                  0                    0
# 4                     0                  0                    0
#
#    Manufacturer_Subaru  Manufacturer_Toyota  Manufacturer_Volkswagen  \
# 0                    0                    0                        0
# 1                    0                    0                        0
# 2                    0                    0                        0
# 3                    0                    0                        0
# 4                    0                    0                        0
#
#    Manufacturer_Volvo  Vehicle_type_Passenger
# 0                   0                       1
# 1                   0                       1
# 2                   0                       1
# 3                   0                       1
# 4                   0                       1
#
# [5 rows x 42 columns]

# %%
cars_new.shape
# Out:
# (157, 42)

# %% [markdown]
# ### assumptions check

# %%
# Very first assumtion is that all the variables should be normally distributed, however that can't be possible
# However we have to be atleast strict about the dependant Y variable

# Distribution of variables
sns.distplot(cars_new.Sales_in_thousands)
plt.show()
# this distribution is highly skewed

# Notes:
#-----------------------------------------------------
# 1. if we get skewed data, then we have to transform the data and there are multiple methods to go about it
# 2. most commonly used and which works on most of the data is log transformation
# 3. Ideally we can do this for each of the dependant variable as well, 
#    however it will depend on amount of data and the amount of analytical rigour
# 4. In no case we can proceed if dependant variable is not normal/near to normal distributed
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
cars_new.Sales_in_thousands.skew()
# Out:
# 1.9924932920508793

# %%
# Note: good practice is to take the log of the data plus 1, bcoz we don't have log of zero defined
# In thios data its not required as sales are always greater than zero

# apply log transformation: log is rescalling the data and making the distribution normal
cars_new.loc[:, 'ln_sales_in_thousands'] = np.log(cars_new.loc[:, 'Sales_in_thousands'])

# Distribution of variables
sns.distplot(cars_new.ln_sales_in_thousands)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
cars_new.ln_sales_in_thousands.skew()
# Out:
# -0.5925861100519006

# %%
# Linearity: correlation matrix (ranges from 1 to -1)
corrm = cars_new.corr()
corrm.to_excel('D:/corrm.xlsx')
corrm
# Out:
#                          Sales_in_thousands  four_year_resale_value  \
# Sales_in_thousands                 1.000000           -3.075381e-01
# four_year_resale_value            -0.307538            1.000000e+00
# Price_in_thousands                -0.361572            8.323203e-01
# Engine_size                       -0.014342            4.402582e-01
# Horsepower                        -0.259311            6.796053e-01
# Wheelbase                          0.278280           -3.762379e-02
# Width                              0.093054            1.582115e-01
# Length                             0.200997            2.551744e-02
# Curb_weight                       -0.035282            3.043781e-01
# Fuel_capacity                      0.044446            2.842737e-01
# Fuel_efficiency                    0.036677           -3.643418e-01
# Power_perf_factor                 -0.285253            7.305955e-01
# Manufacturer_Audi                 -0.091205            1.463488e-01
# Manufacturer_BMW                  -0.086395            1.368779e-01
# Manufacturer_Buick                 0.026378           -5.092434e-02
# Manufacturer_Cadillac             -0.090411            7.976190e-02
# Manufacturer_Chevrolet             0.044907           -1.045554e-01
# Manufacturer_Chrysler             -0.083727           -5.793061e-02
# Manufacturer_Dodge                 0.150865           -2.985356e-02
# Manufacturer_Ford                  0.504941           -1.291647e-01
# Manufacturer_Honda                 0.212506           -4.569773e-02
# Manufacturer_Hyundai              -0.012960           -1.482623e-01
# Manufacturer_Infiniti             -0.038134            1.367784e-02
# Manufacturer_Jaguar               -0.049608           -2.425763e-17
# Manufacturer_Jeep                  0.113038           -3.807465e-02
# Manufacturer_Lexus                -0.115402            1.541779e-01
# Manufacturer_Lincoln              -0.054757            2.955527e-02
# Manufacturer_Mercedes_B           -0.163306            2.926126e-01
# Manufacturer_Mercury              -0.039673           -8.258641e-02
# Manufacturer_Mitsubishi           -0.094453           -8.304436e-02
# Manufacturer_Nissan                0.022424           -6.957982e-02
# Manufacturer_Oldsmobile           -0.073745           -1.966108e-02
# Manufacturer_Plymouth             -0.098685           -1.012489e-01
# Manufacturer_Pontiac               0.036853           -7.130299e-02
# Manufacturer_Porsche              -0.114192            5.122451e-01
# Manufacturer_Saab                 -0.079886            4.484484e-17
# Manufacturer_Saturn               -0.054683           -8.712791e-02
# Manufacturer_Subaru               -0.021816            5.774589e-17
# Manufacturer_Toyota                0.133404           -3.055220e-02
# Manufacturer_Volkswagen           -0.056294           -6.244961e-02
# Manufacturer_Volvo                -0.133361            2.124397e-16
# Vehicle_type_Passenger            -0.230252            7.663782e-02
# ln_sales_in_thousands              0.799513           -4.793496e-01
#
#                          Price_in_thousands  Engine_size  Horsepower  \
# Sales_in_thousands                -0.361572    -0.014342   -0.259311
# four_year_resale_value             0.832320     0.440258    0.679605
# Price_in_thousands                 1.000000     0.618230    0.849851
# Engine_size                        0.618230     1.000000    0.815010
# Horsepower                         0.849851     0.815010    1.000000
# Wheelbase                          0.118080     0.518423    0.325247
# Width                              0.328107     0.702618    0.538115
# Length                             0.158161     0.576386    0.420472
# Curb_weight                        0.527230     0.793937    0.637823
# Fuel_capacity                      0.430942     0.698341    0.526554
# Fuel_efficiency                   -0.505995    -0.757170   -0.611060
# Power_perf_factor                  0.906767     0.796880    0.990906
# Manufacturer_Audi                  0.126770    -0.016693    0.092228
# Manufacturer_BMW                   0.057796    -0.050061    0.000029
# Manufacturer_Buick                -0.006355     0.095247    0.064479
# Manufacturer_Cadillac              0.168300     0.269440    0.244264
# Manufacturer_Chevrolet            -0.127385     0.016968   -0.055214
# Manufacturer_Chrysler             -0.051817    -0.050603    0.033558
# Manufacturer_Dodge                -0.061387     0.126538    0.015312
# Manufacturer_Ford                 -0.123784     0.077961   -0.079667
# Manufacturer_Honda                -0.091821    -0.098501   -0.086133
# Manufacturer_Hyundai              -0.150161    -0.152309   -0.152100
# Manufacturer_Infiniti              0.012279    -0.004107    0.063585
# Manufacturer_Jaguar                0.088929    -0.004107    0.083418
# Manufacturer_Jeep                 -0.063500     0.064343   -0.045184
# Manufacturer_Lexus                 0.239369     0.115722    0.229845
# Manufacturer_Lincoln               0.143904     0.259782    0.207477
# Manufacturer_Mercedes_B            0.431095     0.094030    0.220382
# Manufacturer_Mercury              -0.094172     0.020411   -0.081624
# Manufacturer_Mitsubishi           -0.080047    -0.055348   -0.083067
# Manufacturer_Nissan               -0.077049    -0.030053   -0.067190
# Manufacturer_Oldsmobile           -0.024413     0.081682    0.017767
# Manufacturer_Plymouth             -0.054399    -0.095269   -0.057223
# Manufacturer_Pontiac              -0.062676     0.078278   -0.001225
# Manufacturer_Porsche               0.352160     0.016675    0.231413
# Manufacturer_Saab                  0.018604    -0.104754   -0.016932
# Manufacturer_Saturn               -0.170025    -0.191415   -0.227139
# Manufacturer_Subaru               -0.048390    -0.064019   -0.043989
# Manufacturer_Toyota               -0.094643    -0.108099   -0.115857
# Manufacturer_Volkswagen           -0.137820    -0.221271   -0.244956
# Manufacturer_Volvo                 0.051585    -0.153192   -0.011987
# Vehicle_type_Passenger             0.042006    -0.279272   -0.011910
# ln_sales_in_thousands             -0.578170    -0.120983   -0.400528
#
#                          Wheelbase     Width    Length  Curb_weight  \
# Sales_in_thousands        0.278280  0.093054  0.200997    -0.035282
# four_year_resale_value   -0.037624  0.158211  0.025517     0.304378
# Price_in_thousands        0.118080  0.328107  0.158161     0.527230
# Engine_size               0.518423  0.702618  0.576386     0.793937
# Horsepower                0.325247  0.538115  0.420472     0.637823
# Wheelbase                 1.000000  0.681402  0.837566     0.657133
# Width                     0.681402  1.000000  0.700153     0.710589
# Length                    0.837566  0.700153  1.000000     0.622789
# Curb_weight               0.657133  0.710589  0.622789     1.000000
# Fuel_capacity             0.659706  0.648557  0.561884     0.868131
# Fuel_efficiency          -0.499341 -0.585266 -0.419443    -0.829699
# Power_perf_factor         0.288757  0.506650  0.370951     0.630137
# Manufacturer_Audi         0.012553  0.066172  0.022130     0.024442
# Manufacturer_BMW          0.023274 -0.078841 -0.078509    -0.021871
# Manufacturer_Buick        0.078106  0.107058  0.149666     0.050109
# Manufacturer_Cadillac     0.114165  0.177157  0.189585     0.204463
# Manufacturer_Chevrolet   -0.117108 -0.036935 -0.028966    -0.145635
# Manufacturer_Chrysler     0.050539  0.055724  0.143224    -0.024154
# Manufacturer_Dodge        0.254622  0.287593  0.163737     0.109175
# Manufacturer_Ford         0.181895  0.136556  0.157804     0.035709
# Manufacturer_Honda        0.003035 -0.038202 -0.043865    -0.015363
# Manufacturer_Hyundai     -0.123043 -0.123243 -0.128114    -0.165766
# Manufacturer_Infiniti     0.009372 -0.023044  0.039103    -0.004832
# Manufacturer_Jaguar       0.076663  0.010231  0.024364     0.035214
# Manufacturer_Jeep        -0.136287 -0.070555 -0.207287    -0.001397
# Manufacturer_Lexus        0.037294  0.051113  0.035429     0.195071
# Manufacturer_Lincoln      0.147518  0.241432  0.237684     0.245128
# Manufacturer_Mercedes_B  -0.035393 -0.077481 -0.139340     0.118514
# Manufacturer_Mercury      0.068819  0.078727  0.107805     0.029297
# Manufacturer_Mitsubishi  -0.126573 -0.137296 -0.083400    -0.047366
# Manufacturer_Nissan      -0.008182 -0.073168 -0.019721     0.011069
# Manufacturer_Oldsmobile   0.086383  0.004760  0.098376     0.065984
# Manufacturer_Plymouth     0.053996  0.165855 -0.114515    -0.107500
# Manufacturer_Pontiac      0.046301  0.042237  0.096592     0.007662
# Manufacturer_Porsche     -0.260846 -0.060887 -0.149884    -0.094627
# Manufacturer_Saab        -0.045218 -0.073158 -0.014229    -0.045039
# Manufacturer_Saturn      -0.083508 -0.200799 -0.061395    -0.221474
# Manufacturer_Subaru      -0.092184 -0.110250 -0.059538    -0.020137
# Manufacturer_Toyota      -0.094079 -0.115710 -0.103610    -0.070768
# Manufacturer_Volkswagen  -0.203652 -0.187554 -0.304533    -0.161960
# Manufacturer_Volvo       -0.085656 -0.094848 -0.059118    -0.030589
# Vehicle_type_Passenger   -0.383084 -0.241472 -0.129701    -0.519405
# ln_sales_in_thousands     0.270203  0.038309  0.207226    -0.051904
#
#                          Fuel_capacity  ...  Manufacturer_Pontiac  \
# Sales_in_thousands            0.044446  ...              0.036853
# four_year_resale_value        0.284274  ...             -0.071303
# Price_in_thousands            0.430942  ...             -0.062676
# Engine_size                   0.698341  ...              0.078278
# Horsepower                    0.526554  ...             -0.001225
# Wheelbase                     0.659706  ...              0.046301
# Width                         0.648557  ...              0.042237
# Length                        0.561884  ...              0.096592
# Curb_weight                   0.868131  ...              0.007662
# Fuel_capacity                 1.000000  ...             -0.001650
# Fuel_efficiency              -0.821296  ...              0.053939
# Power_perf_factor             0.521901  ...             -0.014084
# Manufacturer_Audi             0.058296  ...             -0.027822
# Manufacturer_BMW             -0.026284  ...             -0.027822
# Manufacturer_Buick           -0.008438  ...             -0.032231
# Manufacturer_Cadillac         0.136282  ...             -0.036154
# Manufacturer_Chevrolet       -0.148950  ...             -0.049156
# Manufacturer_Chrysler        -0.071459  ...             -0.043062
# Manufacturer_Dodge            0.248327  ...             -0.054715
# Manufacturer_Ford             0.080677  ...             -0.054715
# Manufacturer_Honda           -0.041482  ...             -0.036154
# Manufacturer_Hyundai         -0.125573  ...             -0.027822
# Manufacturer_Infiniti         0.011643  ...             -0.015960
# Manufacturer_Jaguar           0.009533  ...             -0.015960
# Manufacturer_Jeep             0.069328  ...             -0.027822
# Manufacturer_Lexus            0.135778  ...             -0.039735
# Manufacturer_Lincoln          0.185778  ...             -0.027822
# Manufacturer_Mercedes_B       0.063292  ...             -0.049156
# Manufacturer_Mercury         -0.006026  ...             -0.039735
# Manufacturer_Mitsubishi       0.019217  ...             -0.043062
# Manufacturer_Nissan           0.014339  ...             -0.043062
# Manufacturer_Oldsmobile       0.013231  ...             -0.039735
# Manufacturer_Plymouth        -0.120266  ...             -0.032231
# Manufacturer_Pontiac         -0.001650  ...              1.000000
# Manufacturer_Porsche         -0.034864  ...             -0.027822
# Manufacturer_Saab            -0.007425  ...             -0.022643
# Manufacturer_Saturn          -0.260342  ...             -0.036154
# Manufacturer_Subaru          -0.046332  ...             -0.022643
# Manufacturer_Toyota          -0.011787  ...             -0.049156
# Manufacturer_Volkswagen      -0.170589  ...             -0.039735
# Manufacturer_Volvo           -0.006026  ...             -0.039735
# Vehicle_type_Passenger       -0.594758  ...              0.042875
# ln_sales_in_thousands        -0.019549  ...              0.099684
#
#                          Manufacturer_Porsche  Manufacturer_Saab  \
# Sales_in_thousands                  -0.114192      -7.988584e-02
# four_year_resale_value               0.512245       4.484484e-17
# Price_in_thousands                   0.352160       1.860392e-02
# Engine_size                          0.016675      -1.047543e-01
# Horsepower                           0.231413      -1.693190e-02
# Wheelbase                           -0.260846      -4.521823e-02
# Width                               -0.060887      -7.315767e-02
# Length                              -0.149884      -1.422854e-02
# Curb_weight                         -0.094627      -4.503929e-02
# Fuel_capacity                       -0.034864      -7.424594e-03
# Fuel_efficiency                     -0.062512      -2.207112e-02
# Power_perf_factor                    0.262396      -1.003440e-02
# Manufacturer_Audi                   -0.019481      -1.585439e-02
# Manufacturer_BMW                    -0.019481      -1.585439e-02
# Manufacturer_Buick                  -0.022568      -1.836680e-02
# Manufacturer_Cadillac               -0.025314      -2.060214e-02
# Manufacturer_Chevrolet              -0.034418      -2.801171e-02
# Manufacturer_Chrysler               -0.030151      -2.453876e-02
# Manufacturer_Dodge                  -0.038311      -3.117949e-02
# Manufacturer_Ford                   -0.038311      -3.117949e-02
# Manufacturer_Honda                  -0.025314      -2.060214e-02
# Manufacturer_Hyundai                -0.019481      -1.585439e-02
# Manufacturer_Infiniti               -0.011175      -9.094668e-03
# Manufacturer_Jaguar                 -0.011175      -9.094668e-03
# Manufacturer_Jeep                   -0.019481      -1.585439e-02
# Manufacturer_Lexus                  -0.027822      -2.264312e-02
# Manufacturer_Lincoln                -0.019481      -1.585439e-02
# Manufacturer_Mercedes_B             -0.034418      -2.801171e-02
# Manufacturer_Mercury                -0.027822      -2.264312e-02
# Manufacturer_Mitsubishi             -0.030151      -2.453876e-02
# Manufacturer_Nissan                 -0.030151      -2.453876e-02
# Manufacturer_Oldsmobile             -0.027822      -2.264312e-02
# Manufacturer_Plymouth               -0.022568      -1.836680e-02
# Manufacturer_Pontiac                -0.027822      -2.264312e-02
# Manufacturer_Porsche                 1.000000      -1.585439e-02
# Manufacturer_Saab                   -0.015854       1.000000e+00
# Manufacturer_Saturn                 -0.025314      -2.060214e-02
# Manufacturer_Subaru                 -0.015854      -1.290323e-02
# Manufacturer_Toyota                 -0.034418      -2.801171e-02
# Manufacturer_Volkswagen             -0.027822      -2.264312e-02
# Manufacturer_Volvo                  -0.027822      -2.264312e-02
# Vehicle_type_Passenger               0.082978       6.753238e-02
# ln_sales_in_thousands               -0.253594      -8.574180e-02
#
#                          Manufacturer_Saturn  Manufacturer_Subaru  \
# Sales_in_thousands                 -0.054683        -2.181588e-02
# four_year_resale_value             -0.087128         5.774589e-17
# Price_in_thousands                 -0.170025        -4.839044e-02
# Engine_size                        -0.191415        -6.401942e-02
# Horsepower                         -0.227139        -4.398854e-02
# Wheelbase                          -0.083508        -9.218360e-02
# Width                              -0.200799        -1.102499e-01
# Length                             -0.061395        -5.953822e-02
# Curb_weight                        -0.221474        -2.013658e-02
# Fuel_capacity                      -0.260342        -4.633177e-02
# Fuel_efficiency                     0.305097         2.113590e-02
# Power_perf_factor                  -0.219001        -4.610427e-02
# Manufacturer_Audi                  -0.025314        -1.585439e-02
# Manufacturer_BMW                   -0.025314        -1.585439e-02
# Manufacturer_Buick                 -0.029326        -1.836680e-02
# Manufacturer_Cadillac              -0.032895        -2.060214e-02
# Manufacturer_Chevrolet             -0.044725        -2.801171e-02
# Manufacturer_Chrysler              -0.039180        -2.453876e-02
# Manufacturer_Dodge                 -0.049783        -3.117949e-02
# Manufacturer_Ford                  -0.049783        -3.117949e-02
# Manufacturer_Honda                 -0.032895        -2.060214e-02
# Manufacturer_Hyundai               -0.025314        -1.585439e-02
# Manufacturer_Infiniti              -0.014521        -9.094668e-03
# Manufacturer_Jaguar                -0.014521        -9.094668e-03
# Manufacturer_Jeep                  -0.025314        -1.585439e-02
# Manufacturer_Lexus                 -0.036154        -2.264312e-02
# Manufacturer_Lincoln               -0.025314        -1.585439e-02
# Manufacturer_Mercedes_B            -0.044725        -2.801171e-02
# Manufacturer_Mercury               -0.036154        -2.264312e-02
# Manufacturer_Mitsubishi            -0.039180        -2.453876e-02
# Manufacturer_Nissan                -0.039180        -2.453876e-02
# Manufacturer_Oldsmobile            -0.036154        -2.264312e-02
# Manufacturer_Plymouth              -0.029326        -1.836680e-02
# Manufacturer_Pontiac               -0.036154        -2.264312e-02
# Manufacturer_Porsche               -0.025314        -1.585439e-02
# Manufacturer_Saab                  -0.020602        -1.290323e-02
# Manufacturer_Saturn                 1.000000        -2.060214e-02
# Manufacturer_Subaru                -0.020602         1.000000e+00
# Manufacturer_Toyota                -0.044725        -2.801171e-02
# Manufacturer_Volkswagen            -0.036154        -2.264312e-02
# Manufacturer_Volvo                 -0.036154        -2.264312e-02
# Vehicle_type_Passenger              0.107827        -6.176742e-02
# ln_sales_in_thousands              -0.035550         3.347594e-02
#
#                          Manufacturer_Toyota  Manufacturer_Volkswagen  \
# Sales_in_thousands                  0.133404                -0.056294
# four_year_resale_value             -0.030552                -0.062450
# Price_in_thousands                 -0.094643                -0.137820
# Engine_size                        -0.108099                -0.221271
# Horsepower                         -0.115857                -0.244956
# Wheelbase                          -0.094079                -0.203652
# Width                              -0.115710                -0.187554
# Length                             -0.103610                -0.304533
# Curb_weight                        -0.070768                -0.161960
# Fuel_capacity                      -0.011787                -0.170589
# Fuel_efficiency                     0.091046                 0.121336
# Power_perf_factor                  -0.113392                -0.225973
# Manufacturer_Audi                  -0.034418                -0.027822
# Manufacturer_BMW                   -0.034418                -0.027822
# Manufacturer_Buick                 -0.039873                -0.032231
# Manufacturer_Cadillac              -0.044725                -0.036154
# Manufacturer_Chevrolet             -0.060811                -0.049156
# Manufacturer_Chrysler              -0.053271                -0.043062
# Manufacturer_Dodge                 -0.067688                -0.054715
# Manufacturer_Ford                  -0.067688                -0.054715
# Manufacturer_Honda                 -0.044725                -0.036154
# Manufacturer_Hyundai               -0.034418                -0.027822
# Manufacturer_Infiniti              -0.019744                -0.015960
# Manufacturer_Jaguar                -0.019744                -0.015960
# Manufacturer_Jeep                  -0.034418                -0.027822
# Manufacturer_Lexus                 -0.049156                -0.039735
# Manufacturer_Lincoln               -0.034418                -0.027822
# Manufacturer_Mercedes_B            -0.060811                -0.049156
# Manufacturer_Mercury               -0.049156                -0.039735
# Manufacturer_Mitsubishi            -0.053271                -0.043062
# Manufacturer_Nissan                -0.053271                -0.043062
# Manufacturer_Oldsmobile            -0.049156                -0.039735
# Manufacturer_Plymouth              -0.039873                -0.032231
# Manufacturer_Pontiac               -0.049156                -0.039735
# Manufacturer_Porsche               -0.034418                -0.027822
# Manufacturer_Saab                  -0.028012                -0.022643
# Manufacturer_Saturn                -0.044725                -0.036154
# Manufacturer_Subaru                -0.028012                -0.022643
# Manufacturer_Toyota                 1.000000                -0.049156
# Manufacturer_Volkswagen            -0.049156                 1.000000
# Manufacturer_Volvo                 -0.049156                -0.039735
# Vehicle_type_Passenger             -0.165280                 0.118509
# ln_sales_in_thousands               0.146886                -0.034545
#
#                          Manufacturer_Volvo  Vehicle_type_Passenger  \
# Sales_in_thousands            -1.333610e-01               -0.230252
# four_year_resale_value         2.124397e-16                0.076638
# Price_in_thousands             5.158511e-02                0.042006
# Engine_size                   -1.531916e-01               -0.279272
# Horsepower                    -1.198690e-02               -0.011910
# Wheelbase                     -8.565596e-02               -0.383084
# Width                         -9.484845e-02               -0.241472
# Length                        -5.911793e-02               -0.129701
# Curb_weight                   -3.058882e-02               -0.519405
# Fuel_capacity                 -6.026328e-03               -0.594758
# Fuel_efficiency                3.709017e-02                0.598061
# Power_perf_factor              9.620400e-04               -0.003672
# Manufacturer_Audi             -2.782194e-02                0.082978
# Manufacturer_BMW              -2.782194e-02                0.082978
# Manufacturer_Buick            -3.223083e-02                0.096127
# Manufacturer_Cadillac         -3.615350e-02                0.025247
# Manufacturer_Chevrolet        -4.915611e-02                0.146607
# Manufacturer_Chrysler         -4.306164e-02                0.058174
# Manufacturer_Dodge            -5.471508e-02               -0.177659
# Manufacturer_Ford             -5.471508e-02               -0.120852
# Manufacturer_Honda            -3.615350e-02               -0.139912
# Manufacturer_Hyundai          -2.782194e-02                0.082978
# Manufacturer_Infiniti         -1.595970e-02                0.047599
# Manufacturer_Jaguar           -1.595970e-02                0.047599
# Manufacturer_Jeep             -2.782194e-02               -0.234767
# Manufacturer_Lexus            -3.973510e-02               -0.032758
# Manufacturer_Lincoln          -2.782194e-02               -0.022937
# Manufacturer_Mercedes_B       -4.915611e-02                0.084229
# Manufacturer_Mercury          -3.973510e-02               -0.032758
# Manufacturer_Mitsubishi       -4.306164e-02               -0.012082
# Manufacturer_Nissan           -4.306164e-02               -0.152594
# Manufacturer_Oldsmobile       -3.973510e-02               -0.032758
# Manufacturer_Plymouth         -3.223083e-02                0.004103
# Manufacturer_Pontiac          -3.973510e-02                0.042875
# Manufacturer_Porsche          -2.782194e-02                0.082978
# Manufacturer_Saab             -2.264312e-02                0.067532
# Manufacturer_Saturn           -3.615350e-02                0.107827
# Manufacturer_Subaru           -2.264312e-02               -0.061767
# Manufacturer_Toyota           -4.915611e-02               -0.165280
# Manufacturer_Volkswagen       -3.973510e-02                0.118509
# Manufacturer_Volvo             1.000000e+00                0.118509
# Vehicle_type_Passenger         1.185087e-01                1.000000
# ln_sales_in_thousands         -1.573388e-01               -0.272796
#
#                          ln_sales_in_thousands
# Sales_in_thousands                    0.799513
# four_year_resale_value               -0.479350
# Price_in_thousands                   -0.578170
# Engine_size                          -0.120983
# Horsepower                           -0.400528
# Wheelbase                             0.270203
# Width                                 0.038309
# Length                                0.207226
# Curb_weight                          -0.051904
# Fuel_capacity                        -0.019549
# Fuel_efficiency                       0.135005
# Power_perf_factor                    -0.447149
# Manufacturer_Audi                    -0.134931
# Manufacturer_BMW                     -0.068309
# Manufacturer_Buick                    0.087507
# Manufacturer_Cadillac                -0.075474
# Manufacturer_Chevrolet                0.098202
# Manufacturer_Chrysler                -0.016323
# Manufacturer_Dodge                    0.087912
# Manufacturer_Ford                     0.345869
# Manufacturer_Honda                    0.155728
# Manufacturer_Hyundai                  0.051359
# Manufacturer_Infiniti                -0.008834
# Manufacturer_Jaguar                  -0.036066
# Manufacturer_Jeep                     0.131423
# Manufacturer_Lexus                   -0.129608
# Manufacturer_Lincoln                 -0.009894
# Manufacturer_Mercedes_B              -0.244774
# Manufacturer_Mercury                  0.028093
# Manufacturer_Mitsubishi              -0.106078
# Manufacturer_Nissan                   0.115543
# Manufacturer_Oldsmobile              -0.074247
# Manufacturer_Plymouth                -0.137141
# Manufacturer_Pontiac                  0.099684
# Manufacturer_Porsche                 -0.253594
# Manufacturer_Saab                    -0.085742
# Manufacturer_Saturn                  -0.035550
# Manufacturer_Subaru                   0.033476
# Manufacturer_Toyota                   0.146886
# Manufacturer_Volkswagen              -0.034545
# Manufacturer_Volvo                   -0.157339
# Vehicle_type_Passenger               -0.272796
# ln_sales_in_thousands                 1.000000
#
# [43 rows x 43 columns]

# %%
# visualize correlation matrix in Seaborn using a heatmap
plt.figure(figsize = (13, 8))
sns.heatmap(cars_new.corr())

# fuel efficiency vs fuel capacity
# Curb weight vs Engine Size

# in case we can't make any concrete decision looking at the variables;
# we can also check on the VAR of the variables into consideration e.g Curb weight vs Wheel base
# Out:
# <AxesSubplot:>

# %%
# no of variables and obs in the final data to be used for modelling
cars_new.shape
# Out:
# (157, 43)

# %% [markdown]
# ### split the data for model building

# %%
# tuple unpacking
a, b = 10, 20

# %%
cars_new.shape
# Out:
# (157, 43)

# %%
# method 1: divide the data into training and testing
train, test = train_test_split( cars_new, test_size = 0.3, random_state = 12345 )

# %%
# method 2: divide the data into training and testing and separate out Y and X variables
# this will be used in sklearn related methods
train_X, test_X, train_y, test_y = train_test_split( cars_new[feature_columns], 
                        cars_new['ln_sales_in_thousands'], test_size = 0.3, random_state = 12345)

# %%
# verify the no of obs in training and testing after split
print('No of obs in training: ', len(train), ' | ', 'No of obs in testing: ', len(test))
# Out:
# No of obs in training:  109  |  No of obs in testing:  48

# %% [markdown]
# ## Form of linear regression
#
# $y = \beta_0 + \beta_1x_1 + \beta_2x_2 + ... + \beta_nx_n$
#
# - $y$ is the response
# - $\beta_0$ is the intercept
# - $\beta_1$ is the coefficient for $x_1$ (the first feature)
# - $\beta_n$ is the coefficient for $x_n$ (the nth feature)
#
# The $\beta$ values are called the **model coefficients**:
#
# - These values are estimated (or "learned") during the model fitting process using the **least squares criterion**.
# - Specifically, we are find the line (mathematically) which minimizes the **sum of squared residuals** (or "sum of squared errors").
# - And once we've learned these coefficients, we can use the model to predict the response.

# %% [markdown]
# ### building a linear regression model

# %% [raw]
# Steps for model building:
# ------------------------------------------------------------------
# Step 1: lm = smf.ols('y ~ x1 + x2 + x3, ...xn', data = train ) # defining Y and X with classs
#
# Step 2: lm.fit()     # building model (estimating the betas)
#
# Step 3: lm.summary() # get the output summary of the model
#
# Step 4: lm.predict(train) # predict the sales on the training data
#
# Step 5: lm.predict(test) # predict the sales on the testing/validation data
#
# Step 6: test the accuracy of the model
#     a.  MAPE: Mean Absolute Percentage Error
#     b.  RMSE: Root Mean Square Error
#     c.  Corelation between actual and predicted
#     d.  Decile analysis: for validation of models - Business validation
#
#
# R square:
# 1 - SSE(best fit) / SSE(no slope)
#
# Adjusted R square:
# 1 - [(1 - R2)(n - 1) / (n - k - 1)]

# %% [markdown]
# ## model 0

# %%
# manual method of defining the model equation
m1_equation = '''ln_sales_in_thousands ~ Fuel_efficiency + Length + Price_in_thousands + 
            Vehicle_type_Passenger + Manufacturer_Ford'''

# %%
lm0 = smf.ols( formula = m1_equation, data = train ).fit()

# %%
print(lm0.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     ln_sales_in_thousands   R-squared:                       0.526
# Model:                               OLS   Adj. R-squared:                  0.503
# Method:                    Least Squares   F-statistic:                     22.83
# Date:                   Sun, 12 Sep 2021   Prob (F-statistic):           2.33e-15
# Time:                           16:33:55   Log-Likelihood:                -139.86
# No. Observations:                    109   AIC:                             291.7
# Df Residuals:                        103   BIC:                             307.9
# Df Model:                              5
# Covariance Type:               nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -4.9651      2.189     -2.268      0.025      -9.307      -0.623
# Fuel_efficiency            0.1142      0.042      2.721      0.008       0.031       0.197
# Length                     0.0388      0.008      4.930      0.000       0.023       0.054
# Price_in_thousands        -0.0393      0.009     -4.290      0.000      -0.057      -0.021
# Vehicle_type_Passenger    -1.0441      0.282     -3.702      0.000      -1.603      -0.485
# Manufacturer_Ford          1.3469      0.382      3.522      0.001       0.588       2.105
# ==============================================================================
# Omnibus:                       19.935   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.787
# Skew:                          -0.879   Prob(JB):                     5.61e-07
# Kurtosis:                       4.803   Cond. No.                     4.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Model 1

# %%
cars_new.shape
# Out:
# (157, 43)

# %%
cars_new.columns.difference( [ 'Sales_in_thousands', 'ln_sales_in_thousands' ] )
# Out:
# Index(['Curb_weight', 'Engine_size', 'Fuel_capacity', 'Fuel_efficiency',
#        'Horsepower', 'Length', 'Manufacturer_Audi', 'Manufacturer_BMW',
#        'Manufacturer_Buick', 'Manufacturer_Cadillac', 'Manufacturer_Chevrolet',
#        'Manufacturer_Chrysler', 'Manufacturer_Dodge', 'Manufacturer_Ford',
#        'Manufacturer_Honda', 'Manufacturer_Hyundai', 'Manufacturer_Infiniti',
#        'Manufacturer_Jaguar', 'Manufacturer_Jeep', 'Manufacturer_Lexus',
#        'Manufacturer_Lincoln', 'Manufacturer_Mercedes_B',
#        'Manufacturer_Mercury', 'Manufacturer_Mitsubishi',
#        'Manufacturer_Nissan', 'Manufacturer_Oldsmobile',
#        'Manufacturer_Plymouth', 'Manufacturer_Pontiac', 'Manufacturer_Porsche',
#        'Manufacturer_Saab', 'Manufacturer_Saturn', 'Manufacturer_Subaru',
#        'Manufacturer_Toyota', 'Manufacturer_Volkswagen', 'Manufacturer_Volvo',
#        'Power_perf_factor', 'Price_in_thousands', 'Vehicle_type_Passenger',
#        'Wheelbase', 'Width', 'four_year_resale_value'],
#       dtype='object')

# %%
model_eq2 = 'ln_sales_in_thousands ~ ' + ' + '.join( cars_new.columns.difference( [ 'Sales_in_thousands', 'ln_sales_in_thousands' ] ) )

# %%
model_eq2
# Out:
# 'ln_sales_in_thousands ~ Curb_weight + Engine_size + Fuel_capacity + Fuel_efficiency + Horsepower + Length + Manufacturer_Audi + Manufacturer_BMW + Manufacturer_Buick + Manufacturer_Cadillac + Manufacturer_Chevrolet + Manufacturer_Chrysler + Manufacturer_Dodge + Manufacturer_Ford + Manufacturer_Honda + Manufacturer_Hyundai + Manufacturer_Infiniti + Manufacturer_Jaguar + Manufacturer_Jeep + Manufacturer_Lexus + Manufacturer_Lincoln + Manufacturer_Mercedes_B + Manufacturer_Mercury + Manufacturer_Mitsubishi + Manufacturer_Nissan + Manufacturer_Oldsmobile + Manufacturer_Plymouth + Manufacturer_Pontiac + Manufacturer_Porsche + Manufacturer_Saab + Manufacturer_Saturn + Manufacturer_Subaru + Manufacturer_Toyota + Manufacturer_Volkswagen + Manufacturer_Volvo + Power_perf_factor + Price_in_thousands + Vehicle_type_Passenger + Wheelbase + Width + four_year_resale_value'

# %%
lm1 = smf.ols( formula = model_eq2, data = train ).fit()

# %%
print( lm1.summary() )
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     ln_sales_in_thousands   R-squared:                       0.700
# Model:                               OLS   Adj. R-squared:                  0.531
# Method:                    Least Squares   F-statistic:                     4.136
# Date:                   Sun, 12 Sep 2021   Prob (F-statistic):           1.36e-07
# Time:                           17:02:31   Log-Likelihood:                -114.83
# No. Observations:                    109   AIC:                             309.7
# Df Residuals:                         69   BIC:                             417.3
# Df Model:                             39
# Covariance Type:               nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -6.8261      4.065     -1.679      0.098     -14.935       1.283
# Curb_weight                 1.2920      0.591      2.186      0.032       0.113       2.471
# Engine_size                 8.3828     15.416      0.544      0.588     -22.371      39.136
# Fuel_capacity              -0.1146      0.060     -1.925      0.058      -0.233       0.004
# Fuel_efficiency             0.1117      0.071      1.567      0.122      -0.031       0.254
# Horsepower                 11.3588     20.880      0.544      0.588     -30.295      53.013
# Length                     -0.0130      0.022     -0.603      0.549      -0.056       0.030
# Manufacturer_Audi           0.3823      0.889      0.430      0.669      -1.392       2.157
# Manufacturer_BMW           -0.2003      0.827     -0.242      0.809      -1.850       1.449
# Manufacturer_Buick          0.4021      0.866      0.464      0.644      -1.325       2.129
# Manufacturer_Cadillac       1.1484      0.845      1.360      0.178      -0.537       2.833
# Manufacturer_Chevrolet      0.4262      0.744      0.573      0.569      -1.059       1.911
# Manufacturer_Chrysler      -0.0219      0.698     -0.031      0.975      -1.414       1.370
# Manufacturer_Dodge          0.6768      0.722      0.938      0.352      -0.763       2.116
# Manufacturer_Ford           1.8010      0.698      2.579      0.012       0.408       3.194
# Manufacturer_Honda          1.0865      0.726      1.497      0.139      -0.361       2.535
# Manufacturer_Hyundai        0.6466      0.817      0.791      0.431      -0.983       2.277
# Manufacturer_Infiniti    5.905e-13   1.08e-12      0.544      0.588   -1.57e-12    2.75e-12
# Manufacturer_Jaguar         0.7986      1.112      0.718      0.475      -1.421       3.018
# Manufacturer_Jeep        7.207e-13   1.32e-12      0.545      0.588   -1.92e-12    3.36e-12
# Manufacturer_Lexus          0.9127      0.754      1.210      0.230      -0.592       2.417
# Manufacturer_Lincoln        0.9773      0.858      1.139      0.259      -0.735       2.690
# Manufacturer_Mercedes_B     0.5492      0.705      0.779      0.439      -0.858       1.956
# Manufacturer_Mercury        0.0543      0.736      0.074      0.941      -1.414       1.523
# Manufacturer_Mitsubishi     0.0317      0.715      0.044      0.965      -1.395       1.459
# Manufacturer_Nissan         0.7848      0.725      1.082      0.283      -0.662       2.232
# Manufacturer_Oldsmobile    -0.5015      0.689     -0.728      0.469      -1.875       0.872
# Manufacturer_Plymouth      -1.0132      0.817     -1.241      0.219      -2.643       0.616
# Manufacturer_Pontiac        0.7885      0.728      1.083      0.282      -0.664       2.241
# Manufacturer_Porsche        2.2115      1.120      1.974      0.052      -0.024       4.447
# Manufacturer_Saab           0.4403      0.882      0.499      0.619      -1.319       2.199
# Manufacturer_Saturn        -0.8413      0.897     -0.938      0.352      -2.631       0.949
# Manufacturer_Subaru         0.7359      1.128      0.652      0.516      -1.515       2.987
# Manufacturer_Toyota         1.0473      0.653      1.603      0.113      -0.256       2.351
# Manufacturer_Volkswagen    -0.1391      0.732     -0.190      0.850      -1.600       1.322
# Manufacturer_Volvo          0.1193      0.706      0.169      0.866      -1.290       1.528
# Power_perf_factor         -32.1130     59.035     -0.544      0.588    -149.884      85.658
# Price_in_thousands         12.2977     22.776      0.540      0.591     -33.138      57.734
# Vehicle_type_Passenger     -0.0003      0.523     -0.001      0.999      -1.044       1.043
# Wheelbase                   0.0900      0.034      2.629      0.011       0.022       0.158
# Width                      -0.0108      0.056     -0.194      0.847      -0.122       0.100
# four_year_resale_value      0.0240      0.028      0.865      0.390      -0.031       0.079
# ==============================================================================
# Omnibus:                       12.929   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               16.003
# Skew:                          -0.651   Prob(JB):                     0.000335
# Kurtosis:                       4.353   Cond. No.                     1.01e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.02e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
